# %% [markdown]
# <a href="https://colab.research.google.com/github/rylan-berry/DeepLearningIndependentStudy/blob/main/ApplicationsOfDeepLearningProblemSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Gemini Problem Set: Applications of Deep Learning (Chapter 12 - Ian Goodfellow)
#
# **Instructions:** Please answer the following conceptual questions based on the provided video: [Deep Learning Lecture: Applications](https://www.youtube.com/watch?v=EQfxFXvP5hA&list=PLPeIMF2dslPysQnBSLhUWYKo_uGV3iRWf&index=21).
#
# 1.  **Image Classification and Object Detection:** Explain the fundamental difference between image classification and object detection tasks in deep learning. Provide a real-world example for each.
#
#   * *Image classification has an element of saying what it's seeing (like identifing animal species from a picture). While object detection just points out an object within an images (deteting a package at you're proch).*
#
# 2.  **Generative Models:** The video touches upon generative models. Describe what generative models aim to achieve and name one common application discussed or implied.
#
#   * *Generative models take the models prediction and says that is the case. Text generation for example first predicts the next word, then we use the prediction and act like it is the next word, then we go onto the next word.*
#
# 3.  **Natural Language Processing (NLP):** Discuss how deep learning has revolutionized Natural Language Processing. What are some key NLP tasks where deep learning models have shown significant improvements over traditional methods?
#
#   * *Machine learning has proven effective at translation (google translate for example). But NLP has also expanded into chatbots, producing life-like messaages.*
#
# 4.  **Speech Recognition:** What are the main challenges in building a robust speech recognition system? How do deep learning models, particularly recurrent neural networks, help in addressing these challenges?
#
#   * *Time tends to be an issue, you'd have to be able to look over a decent length of input to figure out what's what, and it's challenging to hardcode when one word transfers to another. RNNs address this by functioning across time, allowing for that consistant movement through time.*
#
# 5.  **Reinforcement Learning and Deep Learning:** The video might implicitly or explicitly connect deep learning with reinforcement learning. Explain, in your own words, how deep learning can be integrated into reinforcement learning frameworks and what benefits this integration offers.
#
#   * *Reinforcement Learning tends to struggle with decisions about when to explore new options or when to exploit what's currently known. Deep Learning could help manage that.*
#
# 6.  **Recommendation Systems:** How can deep learning be applied to build more effective recommendation systems compared to simpler collaborative filtering methods? What kind of data might deep learning models leverage?
#
#   * *Deep Learning can be used in recomendation algorithms to learn behaviors that might not intially be hardcoded by a person. Deep Learning models can look at every person's history (watch history, interaction history, etc.), and leverage those to predict what a person might watch and recomend such videos to them.*
#
# 7.  **Ethical Considerations:** Beyond the technical aspects, what are some ethical considerations or potential societal impacts of deploying deep learning applications widely? Think about biases, privacy, and job displacement.
#
#   * *Deep Learning models take on the biases of their training data, a few years ago I heard from a breast cancer detection company about how their model intially solely used hospital location for the data, which as you could guess doesn't actually say anything specific about the patients, nor actually look at the physical conditions of the patient. Another example was a company tried to have an AI pick who'd be a good hire based on past training data, but because older data generally picked male over female, the AI did the same, taking human biases into a digital process. Privacy is also a concern because the data for these things has to come from somewhere, and especially when it has to do with data about people, concerns arrive about that information being leaked (whether through mismanagment or the AI giving it away). And job displacement is a real concern, especially if AI is used to automate existing roles, then those people will lose their jobs to AI. All of these factors are important considerations when developing AI, how do you avoid or remediate biases, privacy leaks, and job loss?*
#
# 8.  **Future Trends:** Based on the topics discussed in the video, what do you foresee as a significant emerging application or research direction for deep learning in the next few years?
#
#   * *At this point in time video generation and chatbots have already come to fruition. But since the world has seen the power of AI, I expect many new things to pop up. For example, more medical applications like cancer detection, most of the challenge is data (because of HIPAA and just lack of digital information). Or automated TSA scans at airports. The sky is the limit!*
